# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/jhk/Desktop/MachineLearning'

# %%
df = pd.read_csv('../Castiel/core/predictMedian/fb_two_hours.csv', sep=';', engine='python')

# %%
df
# Out:
#         id  reqId        time    open    high     low   close  volume     wap  \
# 0        0   1000  1538061505  169.79  169.80  169.79  169.79       6  169.79
# 1        1   1000  1538061510  169.79  169.80  169.78  169.78      31  169.79
# 2        2   1000  1538061515  169.78  169.78  169.78  169.78       2  169.78
# 3        3   1000  1538061520  169.77  169.77  169.74  169.75      30  169.75
# 4        4   1000  1538061525  169.74  169.75  169.74  169.75      20  169.74
# 5        5   1000  1538061530  169.74  169.76  169.74  169.75      15  169.75
# 6        6   1000  1538061535  169.76  169.76  169.75  169.76      28  169.76
# 7        7   1000  1538061540  169.77  169.78  169.75  169.78       9  169.78
# 8        8   1000  1538061545  169.76  169.78  169.73  169.73      14  169.75
# 9        9   1000  1538061550  169.74  169.76  169.74  169.76       9  169.75
# 10      10   1000  1538061555  169.76  169.76  169.75  169.75      18  169.75
# ...

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_model = MinMaxScaler()

# %%
data = df.values
scaler_model.fit(data)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler_model.transform(data)
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         7.45156483e-03, 1.72268908e-01, 1.13636364e-02],
#        [7.05218618e-04, 0.00000000e+00, 6.94444461e-04, ...,
#         4.47093890e-02, 1.72268908e-01, 3.40909091e-02],
#        [1.41043724e-03, 0.00000000e+00, 1.38888889e-03, ...,
#         1.49031297e-03, 1.68067227e-01, 0.00000000e+00],
#        ...,
#        [9.98589563e-01, 0.00000000e+00, 9.98611111e-01, ...,
#         9.53800298e-02, 6.00840336e-01, 1.06060606e-01],
#        [9.99294781e-01, 0.00000000e+00, 9.99305556e-01, ...,
#         6.25931446e-02, 6.05042017e-01, 8.33333333e-02],
#        [1.00000000e+00, 0.00000000e+00, 1.00000000e+00, ...,
#         7.15350224e-02, 6.09243697e-01, 7.19696970e-02]])

# %%
X = df[['wap','count']]

# %%
y = df['minute_median'] # add full minute median to each 5s row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'minute_median'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-6942f3c60559> in <module>()
# ----> 1 y = df['minute_median']
#
# ...
